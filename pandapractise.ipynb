# %%
! pip install pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Pandas used for import and export , cleaning and used to analyse big data , used for working with csv and xlsx file**

# %%
dic={
    "Name":["Ram","Shyam","Sameer","Kajal","Irfan","Rohit"],
    "Roll no":[1,2,3,4,5,6],
    "Grades":["A","B","C","D","E","F"],
    "Email":["abc@xyz.com","def@xyz.com","ghi@xyz.com","jkl@xyz.com","mno@xyz.com","pqr@xyz.com"]
}
dic
# Out:
# {'Name': ['Ram', 'Shyam', 'Sameer', 'Kajal', 'Irfan', 'Rohit'],
#  'Roll no': [1, 2, 3, 4, 5, 6],
#  'Grades': ['A', 'B', 'C', 'D', 'E', 'F'],
#  'Email': ['abc@xyz.com',
#   'def@xyz.com',
#   'ghi@xyz.com',
#   'jkl@xyz.com',
#   'mno@xyz.com',
#   'pqr@xyz.com']}

# %%
df=pd.DataFrame(dic) #dataframe makes table of the data
df
# Out:
#      Name  Roll no Grades        Email
# 0     Ram        1      A  abc@xyz.com
# 1   Shyam        2      B  def@xyz.com
# 2  Sameer        3      C  ghi@xyz.com
# 3   Kajal        4      D  jkl@xyz.com
# 4   Irfan        5      E  mno@xyz.com
# 5   Rohit        6      F  pqr@xyz.com

# %%
df1=pd.Series(dic) #series used for making 1d array
df1
# Out:
# Name               [Ram, Shyam, Sameer, Kajal, Irfan, Rohit]
# Roll no                                   [1, 2, 3, 4, 5, 6]
# Grades                                    [A, B, C, D, E, F]
# Email      [abc@xyz.com, def@xyz.com, ghi@xyz.com, jkl@xy...
# dtype: object

# %%
df.head()# for top 5
# Out:
#      Name  Roll no Grades        Email
# 0     Ram        1      A  abc@xyz.com
# 1   Shyam        2      B  def@xyz.com
# 2  Sameer        3      C  ghi@xyz.com
# 3   Kajal        4      D  jkl@xyz.com
# 4   Irfan        5      E  mno@xyz.com

# %%
df.tail() # tail for last 5
# Out:
#      Name  Roll no Grades        Email
# 1   Shyam        2      B  def@xyz.com
# 2  Sameer        3      C  ghi@xyz.com
# 3   Kajal        4      D  jkl@xyz.com
# 4   Irfan        5      E  mno@xyz.com
# 5   Rohit        6      F  pqr@xyz.com

# %%
df.head(2)
# Out:
#     Name  Roll no Grades        Email
# 0    Ram        1      A  abc@xyz.com
# 1  Shyam        2      B  def@xyz.com

# %%
df.describe() #description about all the numerical values
# Out:
#         Roll no
# count  6.000000
# mean   3.500000
# std    1.870829
# min    1.000000
# 25%    2.250000
# 50%    3.500000
# 75%    4.750000
# max    6.000000

# %%
cus=pd.read_csv('Customer Table Level 1.csv') # for reading csv files
cus
# Out:
#     CustomerID                        Company Name       Costumer Name  \
# 0            1                 Alfreds Futterkiste        Maria Anders
# 1            2  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2            3             Antonio Moreno Taqueria      Antonio Moreno
# 3            4                     Around the Horn        Thomas Hardy
# 4            5                   Berglunds snabbkp  Christina Berglund
# ..         ...                                 ...                 ...
# 86          87                      Wartian Herkku    Pirkko Koskitalo
# 87          88              Wellington Importadora       Paula Parente
# 88          89                White Clover Markets      Karl Jablonski
# 89          90                         Wilman Kala     Matti Karttunen
# 90          91                              Wolski             Zbyszek
#
#            City  PostalCode  Country
# 0        Berlin       12209  Germany
# 1   Mexico D.F.        5021   Mexico
# ...

# %%
type(cus)
# Out:
# pandas.core.frame.DataFrame

# %%
type(cus['CustomerID'])
# Out:
# pandas.core.series.Series

# %%
cus.index
# Out:
# RangeIndex(start=0, stop=91, step=1)

# %%
cus.columns
# Out:
# Index(['CustomerID', 'Company Name', 'Costumer Name', 'City', 'PostalCode',
#        'Country'],
#       dtype='object')

# %%
cus.to_numpy() # to make it in array
# Out:
# array([[1, 'Alfreds Futterkiste', 'Maria Anders', 'Berlin', 12209,
#         'Germany'],
#        [2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo',
#         'Mexico D.F.', 5021, 'Mexico'],
#        [3, 'Antonio Moreno Taqueria', 'Antonio Moreno', 'Mexico D.F.',
#         5023, 'Mexico'],
#        [4, 'Around the Horn', 'Thomas Hardy', 'London', 34626, 'UK'],
#        [5, 'Berglunds snabbkp', 'Christina Berglund', 'Lulea', 95822,
#         'Sweden'],
#        [6, 'Blauer See Delikatessen', 'Hanna Moos', 'Mannheim', 68306,
#         'Germany'],
#        [7, 'Blondel pere et fils', 'Frederique Citeaux', 'Strasbourg',
#         67000, 'France'],
#        [8, 'BOlido Comidas preparadas', 'Martin Sommer', 'Madrid', 28023,
#         'Spain'],
#        [9, 'Bon app', 'Laurence Lebihans', 'Marseille', 13008, 'France'],
#        [10, 'Bottom-Dollar Marketse', 'Elizabeth Lincoln', 'Tsawassen',
#         254685, 'Canada'],
# ...

# %%
cus.drop(0) #remove 0th row
# Out:
#     CustomerID                        Company Name       Costumer Name  \
# 1            2  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2            3             Antonio Moreno Taqueria      Antonio Moreno
# 3            4                     Around the Horn        Thomas Hardy
# 4            5                   Berglunds snabbkp  Christina Berglund
# 5            6             Blauer See Delikatessen          Hanna Moos
# ..         ...                                 ...                 ...
# 86          87                      Wartian Herkku    Pirkko Koskitalo
# 87          88              Wellington Importadora       Paula Parente
# 88          89                White Clover Markets      Karl Jablonski
# 89          90                         Wilman Kala     Matti Karttunen
# 90          91                              Wolski             Zbyszek
#
#            City  PostalCode  Country
# 1   Mexico D.F.        5021   Mexico
# 2   Mexico D.F.        5023   Mexico
# ...

# %%
cus.loc[(48,68),('Company Name',	'Costumer Name')] #for getting data from the table
# Out:
#                     Company Name     Costumer Name
# 48  Magazzini Alimentari Riuniti  Giovanni Rovelli
# 68              Romero y tomillo  Alejandra Camino

# %%
cus.loc[((np.arange(48,78))),('Company Name',	'Costumer Name'	)] #for getting data in some range
# Out:
#                     Company Name        Costumer Name
# 48  Magazzini Alimentari Riuniti     Giovanni Rovelli
# 49                  Maison Dewey      Catherine Dewey
# 50                Mere Paillarde       Jean Fresniere
# 51        Morgenstern Gesundkost      Alexander Feuer
# 52                   North/South       Simon Crowther
# 53        Oceano Atlantico Ltda.       Yvonne Moncada
# 54        Old World Delicatessen        Rene Phillips
# 55            Ottilies Kaseladen  Henriette Pfalzheim
# 56             Paris specialites       Marie Bertrand
# 57     Pericles Comidas clasicas  Guillermo Fernandez
# 58              Piccolo und mehr          Georg Pipps
# 59       Princesa Isabel Vinhoss     Isabel de Castro
# 60                   Que Delicia     Bernardo Batista
# 61                 Queen Cozinha       Lucia Carvalho
# 62                    QUICK-Stop          Horst Kloss
# 63                 Rancho grande     Sergio Gutierrez
# ...

# %%
cus.loc[np.arange(48,78),:]  #return values of all columns
# Out:
#     CustomerID                  Company Name        Costumer Name  \
# 48          49  Magazzini Alimentari Riuniti     Giovanni Rovelli
# 49          50                  Maison Dewey      Catherine Dewey
# 50          51                Mere Paillarde       Jean Fresniere
# 51          52        Morgenstern Gesundkost      Alexander Feuer
# 52          53                   North/South       Simon Crowther
# 53          54        Oceano Atlantico Ltda.       Yvonne Moncada
# 54          55        Old World Delicatessen        Rene Phillips
# 55          56            Ottilies Kaseladen  Henriette Pfalzheim
# 56          57             Paris specialites       Marie Bertrand
# 57          58     Pericles Comidas clasicas  Guillermo Fernandez
# 58          59              Piccolo und mehr          Georg Pipps
# 59          60       Princesa Isabel Vinhoss     Isabel de Castro
# 60          61                   Que Delicia     Bernardo Batista
# ...

# %%
CN=cus.loc[:,'Company Name']
CN
# Out:
# 0                    Alfreds Futterkiste
# 1     Ana Trujillo Emparedados y helados
# 2                Antonio Moreno Taqueria
# 3                        Around the Horn
# 4                      Berglunds snabbkp
#                      ...
# 86                        Wartian Herkku
# 87                Wellington Importadora
# 88                  White Clover Markets
# 89                           Wilman Kala
# 90                                Wolski
# Name: Company Name, Length: 91, dtype: object

# %%
np.array(cus.loc[:,'Company Name'])
# Out:
# array(['Alfreds Futterkiste', 'Ana Trujillo Emparedados y helados',
#        'Antonio Moreno Taqueria', 'Around the Horn', 'Berglunds snabbkp',
#        'Blauer See Delikatessen', 'Blondel pere et fils',
#        'BOlido Comidas preparadas', 'Bon app', 'Bottom-Dollar Marketse',
#        'Bs Beverages', 'Cactus Comidas para llevar',
#        'Centro comercial Moctezuma', 'Chop-suey Chinese',
#        'Comercio Mineiro', 'Consolidated Holdings',
#        'Drachenblut Delikatessend', 'Du monde entier',
#        'Eastern Connection', 'Ernst Handel', 'Familia Arquibaldo',
#        'FISSA Fabrica Inter. Salchichas S.A.', 'Folies gourmandes',
#        'Folk och fa HB', 'Frankenversand', 'France restauration',
#        'Franchi S.p.A.', 'Furia Bacalhau e Frutos do Mar',
#        'Galeria del gastrOnomo', 'Godos Cocina Tipica',
#        'Gourmet Lanchonetes', 'Great Lakes Food Market',
#        'GROSELLA-Restaurante', 'Hanari Carnes', 'HILARION-Abastos',
# ...

# %%
company_data=employees = [
    {"company": "Tech Solutions", "employee_name": "Alice Johnson", "position": "Software Engineer"},
    {"company": "Innovative Tech", "employee_name": "Bob Smith", "position": "Data Scientist"},
    {"company": "Creative Minds", "employee_name": "Carol White", "position": "Graphic Designer"},
    {"company": "Tech Solutions", "employee_name": "David Brown", "position": "System Administrator"},
    {"company": "Future Vision", "employee_name": "Eve Black", "position": "Product Manager"},
    {"company": "Tech Solutions", "employee_name": "Frank Green", "position": "DevOps Engineer"},
    {"company": "Innovative Tech", "employee_name": "Grace Harris", "position": "Machine Learning Engineer"},
    {"company": "Creative Minds", "employee_name": "Hank Lewis", "position": "UX Designer"},
    {"company": "Future Vision", "employee_name": "Ivy Wilson", "position": "Project Manager"},
    {"company": "Tech Solutions", "employee_name": "Jack Miller", "position": "Network Engineer"},
    {"company": "Innovative Tech", "employee_name": "Kathy Moore", "position": "Data Analyst"},
    {"company": "Creative Minds", "employee_name": "Liam Taylor", "position": "Content Writer"},
    {"company": "Future Vision", "employee_name": "Mia Anderson", "position": "Marketing Specialist"},
    {"company": "Tech Solutions", "employee_name": "Noah Thompson", "position": "Security Analyst"},
    {"company": "Innovative Tech", "employee_name": "Olivia Garcia", "position": "Software Developer"},
    {"company": "Creative Minds", "employee_name": "Paul Martinez", "position": "Illustrator"},
    {"company": "Future Vision", "employee_name": "Quinn Robinson", "position": "Sales Manager"},
    {"company": "Tech Solutions", "employee_name": "Rachel Clark", "position": "Technical Support"},
    {"company": "Innovative Tech", "employee_name": "Sam Walker", "position": "Cloud Architect"},
    {"company": "Creative Minds", "employee_name": "Tina Hall", "position": "Animator"},
    {"company": "Future Vision", "employee_name": "Uma Allen", "position": "HR Specialist"},
    {"company": "Tech Solutions", "employee_name": "Victor Young", "position": "IT Consultant"},
    {"company": "Innovative Tech", "employee_name": "Wendy King", "position": "Business Analyst"},
    {"company": "Creative Minds", "employee_name": "Xander Wright", "position": "Art Director"},
    {"company": "Future Vision", "employee_name": "Yara Scott", "position": "Operations Manager"},
    {"company": "Tech Solutions", "employee_name": "Zane Baker", "position": "Database Administrator"},
    {"company": "Innovative Tech", "employee_name": "Abby Rivera", "position": "QA Engineer"},
    {"company": "Creative Minds", "employee_name": "Ben Cooper", "position": "Copywriter"},
    {"company": "Future Vision", "employee_name": "Cindy Parker", "position": "Account Manager"},
    {"company": "Tech Solutions", "employee_name": "Dan Evans", "position": "Frontend Developer"},
    {"company": "Innovative Tech", "employee_name": "Ella Collins", "position": "Backend Developer"},
    {"company": "Creative Minds", "employee_name": "Finn Carter", "position": "Photographer"},
    {"company": "Future Vision", "employee_name": "Gina Edwards", "position": "Social Media Manager"},
    {"company": "Tech Solutions", "employee_name": "Henry Flores", "position": "IT Support"},
    {"company": "Innovative Tech", "employee_name": "Isla Hughes", "position": "AI Specialist"},
    {"company": "Creative Minds", "employee_name": "Jake Ross", "position": "Video Editor"},
    {"company": "Future Vision", "employee_name": "Kara Diaz", "position": "Public Relations"},
    {"company": "Tech Solutions", "employee_name": "Leo Reed", "position": "Software Tester"},
    {"company": "Innovative Tech", "employee_name": "Molly Lee", "position": "Blockchain Developer"},
    {"company": "Creative Minds", "employee_name": "Nate Perez", "position": "Sound Engineer"},
    {"company": "Future Vision", "employee_name": "Olga Sanchez", "position": "Event Coordinator"},
    {"company": "Tech Solutions", "employee_name": "Pete Ramirez", "position": "Web Developer"},
    {"company": "Innovative Tech", "employee_name": "Quincy Butler", "position": "Systems Analyst"},
    {"company": "Creative Minds", "employee_name": "Rita Barnes", "position": "Fashion Designer"},
    {"company": "Future Vision", "employee_name": "Steve Foster", "position": "Customer Service"},
    {"company": "Tech Solutions", "employee_name": "Tara Gonzalez", "position": "Mobile App Developer"},
    {"company": "Innovative Tech", "employee_name": "Ulysses Brooks", "position": "IT Manager"},
    {"company": "Creative Minds", "employee_name": "Vera Price", "position": "Interior Designer"},
    {"company": "Future Vision", "employee_name": "Will Murphy", "position": "Digital Strategist"}
]
company_data
# Out:
# [{'company': 'Tech Solutions',
#   'employee_name': 'Alice Johnson',
#   'position': 'Software Engineer'},
#  {'company': 'Innovative Tech',
#   'employee_name': 'Bob Smith',
#   'position': 'Data Scientist'},
#  {'company': 'Creative Minds',
#   'employee_name': 'Carol White',
#   'position': 'Graphic Designer'},
#  {'company': 'Tech Solutions',
#   'employee_name': 'David Brown',
#   'position': 'System Administrator'},
#  {'company': 'Future Vision',
#   'employee_name': 'Eve Black',
#   'position': 'Product Manager'},
#  {'company': 'Tech Solutions',
#   'employee_name': 'Frank Green',
#   'position': 'DevOps Engineer'},
#  {'company': 'Innovative Tech',
#   'employee_name': 'Grace Harris',
#   'position': 'Machine Learning Engineer'},
#  {'company': 'Creative Minds',
#   'employee_name': 'Hank Lewis',
#   'position': 'UX Designer'},
#  {'company': 'Future Vision',
#   'employee_name': 'Ivy Wilson',
#   'position': 'Project Manager'},
#  {'company': 'Tech Solutions',
# ...

# %%
company_data.drop_duplicates(subset='company',keep=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 company_data.drop_duplicates(subset='company',keep=True)
#
# AttributeError: 'list' object has no attribute 'drop_duplicates'
