# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # reading csv file

# %%
from matplotlib import pyplot as plt
sm=pd.read_csv('student_marks.csv')
sm
# Out:
#      Roll No                     Name  English  Hindi  Maths  Science  SST
# 0          1            A HariCharan        80     66     98       21   41
# 1          2  A Mohammed Sahil Aiyan        72     73     81       56   83
# 2          3           A Pavan Kumar        41     46     26        7   35
# 3          4            Aaditya Nanda       64     99      6       16   72
# 4          5        Aakanksha Kaushal       38     20     40       33   50
# ..       ...                      ...      ...    ...    ...      ...  ...
# 554      555           Yamini Priya K       57     52     77       95   77
# 555      556         YARUKALA ALEKHYA       11     24     18       28    5
# 556      557           YOGESH KOTHARI        8     12     29       32   32
# 557      558       ZAKKAM ABHIGNA RAJ       85     72     97       90   79
# 558      559               Zoha Shaik       95     86     59       81   77
#
# [559 rows x 7 columns]

# %%
sm.head(2)
# Out:
#    Roll No                     Name  English  Hindi  Maths  Science  SST
# 0        1            A HariCharan        80     66     98       21   41
# 1        2  A Mohammed Sahil Aiyan        72     73     81       56   83

# %%
sm['Total']=sm[['English','Hindi','Maths','Science','SST']].sum(axis=1)
sm
# Out:
#      Roll No                     Name  English  Hindi  Maths  Science  SST  \
# 0          1            A HariCharan        80     66     98       21   41
# 1          2  A Mohammed Sahil Aiyan        72     73     81       56   83
# 2          3           A Pavan Kumar        41     46     26        7   35
# 3          4            Aaditya Nanda       64     99      6       16   72
# 4          5        Aakanksha Kaushal       38     20     40       33   50
# ..       ...                      ...      ...    ...    ...      ...  ...
# 554      555           Yamini Priya K       57     52     77       95   77
# 555      556         YARUKALA ALEKHYA       11     24     18       28    5
# 556      557           YOGESH KOTHARI        8     12     29       32   32
# 557      558       ZAKKAM ABHIGNA RAJ       85     72     97       90   79
# 558      559               Zoha Shaik       95     86     59       81   77
#
#      Total
# 0      306
# 1      365
# 2      155
# 3      257
# ...

# %%
sm['Percentage']=sm['Total']/5
sm
# Out:
#      Roll No                     Name  English  Hindi  Maths  Science  SST  \
# 0          1            A HariCharan        80     66     98       21   41
# 1          2  A Mohammed Sahil Aiyan        72     73     81       56   83
# 2          3           A Pavan Kumar        41     46     26        7   35
# 3          4            Aaditya Nanda       64     99      6       16   72
# 4          5        Aakanksha Kaushal       38     20     40       33   50
# ..       ...                      ...      ...    ...    ...      ...  ...
# 554      555           Yamini Priya K       57     52     77       95   77
# 555      556         YARUKALA ALEKHYA       11     24     18       28    5
# 556      557           YOGESH KOTHARI        8     12     29       32   32
# 557      558       ZAKKAM ABHIGNA RAJ       85     72     97       90   79
# 558      559               Zoha Shaik       95     86     59       81   77
#
#      Total  Percentage
# 0      306        61.2
# ...

# %%
#Grading
# A=100-80 
# B=80-60
# C=60-50
# D=50-40
# E=40-30
# F=0-30
def calc_grade(p):
    if p<=100 and p>=80:
        return 'A'
    elif p<80 and p>=60:
        return 'B'
    elif p<60 and p>=50:
        return 'C'
    elif p<50 and p>=40:
        return 'D'
    elif p<40 and p>=30:
        return 'E'
    elif p<30 and p>=0:
        return 'F'
    else:
        return 'X'

sm['Grade']=sm['Percentage'].apply(calc_grade) #apply for applying somefunction on some attribute
sm
# Out:
#      Roll No                     Name  English  Hindi  Maths  Science  SST  \
# 0          1            A HariCharan        80     66     98       21   41
# 1          2  A Mohammed Sahil Aiyan        72     73     81       56   83
# 2          3           A Pavan Kumar        41     46     26        7   35
# 3          4            Aaditya Nanda       64     99      6       16   72
# 4          5        Aakanksha Kaushal       38     20     40       33   50
# ..       ...                      ...      ...    ...    ...      ...  ...
# 554      555           Yamini Priya K       57     52     77       95   77
# 555      556         YARUKALA ALEKHYA       11     24     18       28    5
# 556      557           YOGESH KOTHARI        8     12     29       32   32
# 557      558       ZAKKAM ABHIGNA RAJ       85     72     97       90   79
# 558      559               Zoha Shaik       95     86     59       81   77
#
#      Total  Percentage Grade
# 0      306        61.2     B
# ...

# %%
temp=sm.head()
temp
# Out:
#    Roll No                     Name  English  Hindi  Maths  Science  SST  \
# 0        1            A HariCharan        80     66     98       21   41
# 1        2  A Mohammed Sahil Aiyan        72     73     81       56   83
# 2        3           A Pavan Kumar        41     46     26        7   35
# 3        4            Aaditya Nanda       64     99      6       16   72
# 4        5        Aakanksha Kaushal       38     20     40       33   50
#
#    Total  Percentage Grade
# 0    306        61.2     B
# 1    365        73.0     B
# 2    155        31.0     E
# 3    257        51.4     C
# 4    181        36.2     E

# %%
 #1 xaxis and 2nd yaxis
#for changing color we have to make array and allot different colours

for sub in ['English','Hindi','Maths','Science','SST']:
    plt.figure(figsize=(10,6))
    plt.plot(temp['Name'],temp[sub],marker='o',color='red',label=sub) #marker brings o in the graph
    plt.title("Marks in Different Subjects")
    plt.xlabel('Name')
    plt.ylabel('Marks')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
#for changing color we have to make array and allot different colours
sub=['English','Hindi','Maths','Science','SST']

# for i in range(5):
plt.figure(figsize=(10,6))
plt.plot(temp['Name'],temp[sub],marker='o',label=sub) #marker brings o in the graph
plt.title("Marks in Different Subjects")
plt.xlabel('Name')
plt.ylabel('Marks')
plt.legend()
plt.grid(True)
plt.show()
#this is how we change colour
